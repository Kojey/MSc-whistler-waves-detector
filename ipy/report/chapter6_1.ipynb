# %% [markdown]
# # Chapter 7
# ## Detection Using Neural Networks

# %%
import os, sys
import numpy as np
from math import floor
import pickle
from matplotlib import pyplot as plt
from matplotlib.ticker import FormatStrFormatter
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
from tqdm import tqdm
import h5py
from scipy import signal
import multiprocessing as mp


from sklearn import model_selection,preprocessing
# os.environ['THEANO_FLAGS'] = "device=cuda,force_device=True,floatX=float32"
# os.environ["KERAS_BACKEND"] = "theano"
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dropout, MaxPooling2D, Dense, Flatten, Input
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.regularizers import l1,l2, l1_l2
from tensorflow.keras.utils import plot_model, to_categorical



# import python library
sys.path.append(os.path.join(os.getcwd().split(os.environ.get('USER'))[0],os.environ.get('USER'), 'wdml', 'py'))
from sample import Sample
from dataset import Dataset
from database import Database
from yolo_data_aug import YOLODataAug
from yolo_detector import YOLODetector
from nn_detector import NeuralNetworkDetector

dataset_loc = os.path.join(os.getcwd().split(os.environ.get('USER'))[0],os.environ.get('USER'), 'wdml', 'data','datasets', 'awdEvents1')
database_loc = os.path.join(os.getcwd().split(os.environ.get('USER'))[0],os.environ.get('USER'), 'wdml', 'data','databases', 'awdEvents1')
dataset_sim_loc = os.path.join(os.getcwd().split(os.environ.get('USER'))[0],os.environ.get('USER'), 'wdml', 'data','datasets', 'simulations', 'simple' ,'whistler')
result_loc = os.path.join(os.getcwd().split(os.environ.get('USER'))[0],os.environ.get('USER'), 'wdml', 'data','results', 'awdEvents1')
site = 'marion'
database = Database(dataset_loc, database_loc, site)


linewidth = 2
font_title = 32
font_legend = 20
font_label = 24
font_ticks = 18
font = [font_title, font_legend, font_label, font_ticks, linewidth] # [None]*5

# use gpu
# print('GPUs:',K.tensorflow_backend._get_available_gpus())
# gpu_options = tf.GPUOptions(allow_growth=True)
# session = tf.InteractiveSession(config=tf.ConfigProto(gpu_options=gpu_options))

# %% [markdown]
# ##  **6.2 Classifier Design**

# %% [markdown]
# ### Dataset

# %% [markdown]
# **Generate Dataset**

# %%
transforms, transforms_params = ['slice', 'scale'], [[1.5,9.5],[0,1]]
# transforms, transforms_params = ['slice', 'zscore','scale'], [[1.5,9.5],None,[0,1]]
nn = NeuralNetworkDetector(dataset_loc, database_loc, site, transforms, transforms_params)
cut_params = [1,0.2,8,1.5,1]
# database.create_cuts_db_mp(transforms, transforms_params,cut_params, verbose=True, noise=True, train=True, test=False, n=None)

# %% [markdown]
# **Show dataset statistics**

# %%
_ = database.stats(transforms, transforms_params,cut_params, noise=True, test=False)
# Out:
# /srv/home/knnoth001/wdml/data/databases/awdEvents1/marion/marion_h5/['slice', 'scale']_[[1.5, 9.5], [0, 1]]_[1, 0.2, 8, 1.5, 1]_True/train
# samples:  7968
# 100%|██████████| 7968/7968 [00:08<00:00, 907.07it/s]
# Database statistics
# ==================================
# min                   0
# max                   1
# mean                  0.579
# std                   0.112
# noise                 2850[35.77%]
# whistler              5118[64.23%]
# total                 7968

# %% [markdown]
# **Load dataset**

# %%
X , Y = database.load_cuts_db_mp(transforms, transforms_params,cut_params, noise=True, verbose=True, test=False, shuffle=True, random_state=42)
# Out:
# /srv/home/knnoth001/wdml/data/databases/awdEvents1/marion/marion_h5/['slice', 'scale']_[[1.5, 9.5], [0, 1]]_[1, 0.2, 8, 1.5, 1]_True/train
# samples:  7968
# 100%|██████████| 7968/7968 [00:05<00:00, 1448.59it/s]

# %% [markdown]
# **Show few examples**

# %%
x_size = 3
y_size = 3
scale = 3
plt.figure(figsize=(y_size*2*scale, x_size*scale))
for ix in range(x_size*y_size):
    ax = plt.subplot(x_size, y_size, ix+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    index = np.random.randint(len(Y))
    plt.pcolormesh(X[index], cmap='gray')
    ax.set_title('whistler' if Y[index]==1 else 'noise')
plt.show()
plt.figure(figsize=(2*X[179].shape[1]/X[179].shape[0],2))
plt.pcolormesh(X[179], cmap='gray')
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# **Reshape data and label and rescale it**

# %%
freq_len, time_len = X[0].shape
data = X.reshape(len(X),freq_len*time_len)
scaler = preprocessing.StandardScaler().fit(data)
data = scaler.transform(data)
data = data.reshape((len(data),1,freq_len,time_len))
evt = to_categorical(Y)
print(X.shape, Y.shape)
print(data.shape,evt.shape)
print(Y)
# Out:
# (7968, 52, 156) (7968,)
# (7968, 1, 52, 156) (7968, 2)
# [ True False  True ... False  True  True]

# %% [markdown]
# **Define Model**

# %%
model = Sequential()
# model.add(Input(data[0].shape))
model.add(Conv2D(2,(26, 26), input_shape=(1,freq_len, time_len),
                    padding='same', activation='relu',data_format='channels_first'))
model.add(MaxPooling2D(pool_size=(2,2),data_format='channels_first'))
model.add(Dropout(rate=0.5))
model.add(Conv2D(4, (7,7), activation='relu', padding='same',data_format='channels_first'))
model.add(MaxPooling2D(pool_size=(2,2),data_format='channels_first'))
model.add(Dropout(rate=0.4))
model.add(Conv2D(8, (5,5), activation='relu', padding='same',data_format='channels_first'))
# model.add(MaxPooling2D(pool_size=(2,2),data_format='channels_first'))
# model.add(Dropout(rate=0.3))

# model.add(Conv2D(16, (7,7), activation='relu', padding='same',data_format='channels_first'))
# model.add(MaxPooling2D(pool_size=(2,2),data_format='channels_first'))
# model.add(Dropout(rate=0.2))

model.add(Flatten())
# model.add(Dense(512, activation='relu'))
model.add(Dropout(rate=0.2))
model.add(Dense(128, activation='relu'))
model.add(Dropout(rate=0.1))
model.add(Dense(2, activation='softmax'))

#compile model
epochs = 250
lrate = 0.001
decay = lrate/epochs
sgd = SGD(lr=lrate, momentum=0.9, decay=decay, nesterov=False)
adam = Adam(lr=lrate, beta_1=0.9, beta_2=0.999, epsilon=None, decay=decay, amsgrad=False)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 2, 52, 156)        1354
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 26, 78)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2, 26, 78)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 26, 78)         396
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 13, 39)         0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 4, 13, 39)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 13, 39)         808
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4056)              0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 4056)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               519296
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 522,112
# Trainable params: 522,112
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
plot_model(model, show_shapes=True, show_layer_names=False, rankdir='LR', expand_nested=False)

# %% [markdown]
# **Train Model**

# %%
history = model.fit(data, evt, validation_split=0.3, epochs=epochs, batch_size=250, shuffle=True)
# Out:
# Train on 5577 samples, validate on 2391 samples
# Epoch 1/250
# 5577/5577 [==============================] - 2s 388us/sample - loss: 0.6873 - accuracy: 0.5940 - val_loss: 0.6733 - val_accuracy: 0.6332
# Epoch 2/250
# 5577/5577 [==============================] - 1s 262us/sample - loss: 0.6273 - accuracy: 0.6469 - val_loss: 0.6357 - val_accuracy: 0.7001
# Epoch 3/250
# 5577/5577 [==============================] - 1s 260us/sample - loss: 0.5298 - accuracy: 0.7214 - val_loss: 0.4902 - val_accuracy: 0.8084
# Epoch 4/250
# 5577/5577 [==============================] - 1s 260us/sample - loss: 0.4051 - accuracy: 0.8151 - val_loss: 0.3722 - val_accuracy: 0.8578
# Epoch 5/250
# 5577/5577 [==============================] - 1s 261us/sample - loss: 0.3599 - accuracy: 0.8465 - val_loss: 0.3391 - val_accuracy: 0.8825
# Epoch 6/250
# 5577/5577 [==============================] - 1s 262us/sample - loss: 0.3295 - accuracy: 0.8558 - val_loss: 0.3191 - val_accuracy: 0.8887
# Epoch 7/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.3055 - accuracy: 0.8745 - val_loss: 0.2949 - val_accuracy: 0.9034
# Epoch 8/250
# 5577/5577 [==============================] - 1s 262us/sample - loss: 0.2813 - accuracy: 0.8885 - val_loss: 0.2765 - val_accuracy: 0.9101
# Epoch 9/250
# 5577/5577 [==============================] - 1s 262us/sample - loss: 0.2654 - accuracy: 0.8931 - val_loss: 0.2594 - val_accuracy: 0.9159
# Epoch 10/250
# 5577/5577 [==============================] - 1s 262us/sample - loss: 0.2465 - accuracy: 0.9028 - val_loss: 0.2457 - val_accuracy: 0.9184
# Epoch 11/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.2353 - accuracy: 0.9086 - val_loss: 0.2265 - val_accuracy: 0.9272
# Epoch 12/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.2204 - accuracy: 0.9195 - val_loss: 0.2119 - val_accuracy: 0.9368
# Epoch 13/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.2084 - accuracy: 0.9243 - val_loss: 0.2059 - val_accuracy: 0.9360
# Epoch 14/250
# 5577/5577 [==============================] - 1s 261us/sample - loss: 0.2078 - accuracy: 0.9247 - val_loss: 0.1964 - val_accuracy: 0.9460
# Epoch 15/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.1943 - accuracy: 0.9306 - val_loss: 0.1910 - val_accuracy: 0.9414
# Epoch 16/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.1827 - accuracy: 0.9374 - val_loss: 0.1799 - val_accuracy: 0.9477
# Epoch 17/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.1884 - accuracy: 0.9338 - val_loss: 0.1774 - val_accuracy: 0.9502
# Epoch 18/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.1840 - accuracy: 0.9351 - val_loss: 0.1760 - val_accuracy: 0.9536
# Epoch 19/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.1767 - accuracy: 0.9354 - val_loss: 0.1704 - val_accuracy: 0.9506
# Epoch 20/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.1709 - accuracy: 0.9392 - val_loss: 0.1645 - val_accuracy: 0.9540
# Epoch 21/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.1697 - accuracy: 0.9401 - val_loss: 0.1603 - val_accuracy: 0.9552
# Epoch 22/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.1658 - accuracy: 0.9442 - val_loss: 0.1581 - val_accuracy: 0.9565
# Epoch 23/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.1681 - accuracy: 0.9424 - val_loss: 0.1553 - val_accuracy: 0.9565
# Epoch 24/250
# 5577/5577 [==============================] - 1s 262us/sample - loss: 0.1597 - accuracy: 0.9466 - val_loss: 0.1524 - val_accuracy: 0.9548
# Epoch 25/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.1593 - accuracy: 0.9460 - val_loss: 0.1475 - val_accuracy: 0.9578
# Epoch 26/250
# 5577/5577 [==============================] - 1s 262us/sample - loss: 0.1525 - accuracy: 0.9519 - val_loss: 0.1448 - val_accuracy: 0.9582
# Epoch 27/250
# 5577/5577 [==============================] - 1s 265us/sample - loss: 0.1482 - accuracy: 0.9505 - val_loss: 0.1437 - val_accuracy: 0.9590
# Epoch 28/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.1503 - accuracy: 0.9478 - val_loss: 0.1431 - val_accuracy: 0.9603
# Epoch 29/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.1468 - accuracy: 0.9519 - val_loss: 0.1389 - val_accuracy: 0.9594
# Epoch 30/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.1468 - accuracy: 0.9521 - val_loss: 0.1388 - val_accuracy: 0.9611
# Epoch 31/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.1485 - accuracy: 0.9503 - val_loss: 0.1385 - val_accuracy: 0.9624
# Epoch 32/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.1516 - accuracy: 0.9435 - val_loss: 0.1384 - val_accuracy: 0.9619
# Epoch 33/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.1439 - accuracy: 0.9557 - val_loss: 0.1374 - val_accuracy: 0.9624
# Epoch 34/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.1380 - accuracy: 0.9545 - val_loss: 0.1315 - val_accuracy: 0.9611
# Epoch 35/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.1452 - accuracy: 0.9489 - val_loss: 0.1333 - val_accuracy: 0.9624
# Epoch 36/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.1383 - accuracy: 0.9521 - val_loss: 0.1338 - val_accuracy: 0.9628
# Epoch 37/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.1409 - accuracy: 0.9557 - val_loss: 0.1305 - val_accuracy: 0.9632
# Epoch 38/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.1309 - accuracy: 0.9546 - val_loss: 0.1298 - val_accuracy: 0.9645
# Epoch 39/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.1368 - accuracy: 0.9545 - val_loss: 0.1281 - val_accuracy: 0.9640
# Epoch 40/250
# 5577/5577 [==============================] - 1s 262us/sample - loss: 0.1350 - accuracy: 0.9534 - val_loss: 0.1282 - val_accuracy: 0.9645
# Epoch 41/250
# 5577/5577 [==============================] - 1s 262us/sample - loss: 0.1331 - accuracy: 0.9552 - val_loss: 0.1283 - val_accuracy: 0.9653
# Epoch 42/250
# 5577/5577 [==============================] - 1s 266us/sample - loss: 0.1346 - accuracy: 0.9577 - val_loss: 0.1278 - val_accuracy: 0.9645
# Epoch 43/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.1266 - accuracy: 0.9555 - val_loss: 0.1249 - val_accuracy: 0.9645
# Epoch 44/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.1271 - accuracy: 0.9584 - val_loss: 0.1244 - val_accuracy: 0.9653
# Epoch 45/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.1234 - accuracy: 0.9597 - val_loss: 0.1222 - val_accuracy: 0.9657
# Epoch 46/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.1252 - accuracy: 0.9562 - val_loss: 0.1216 - val_accuracy: 0.9657
# Epoch 47/250
# 5577/5577 [==============================] - 1s 265us/sample - loss: 0.1279 - accuracy: 0.9575 - val_loss: 0.1238 - val_accuracy: 0.9661
# Epoch 48/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.1251 - accuracy: 0.9584 - val_loss: 0.1223 - val_accuracy: 0.9645
# Epoch 49/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.1276 - accuracy: 0.9589 - val_loss: 0.1243 - val_accuracy: 0.9665
# Epoch 50/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.1260 - accuracy: 0.9597 - val_loss: 0.1206 - val_accuracy: 0.9653
# Epoch 51/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.1175 - accuracy: 0.9600 - val_loss: 0.1182 - val_accuracy: 0.9657
# Epoch 52/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0
250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.0793 - accuracy: 0.9733 - val_loss: 0.1011 - val_accuracy: 0.9711
# Epoch 139/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.0813 - accuracy: 0.9729 - val_loss: 0.1016 - val_accuracy: 0.9720
# Epoch 140/250
# 5577/5577 [==============================] - 1s 265us/sample - loss: 0.0828 - accuracy: 0.9693 - val_loss: 0.1015 - val_accuracy: 0.9716
# Epoch 141/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.0823 - accuracy: 0.9704 - val_loss: 0.0996 - val_accuracy: 0.9720
# Epoch 142/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.0791 - accuracy: 0.9722 - val_loss: 0.1010 - val_accuracy: 0.9720
# Epoch 143/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.0771 - accuracy: 0.9726 - val_loss: 0.0999 - val_accuracy: 0.9720
# Epoch 144/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.0768 - accuracy: 0.9749 - val_loss: 0.1004 - val_accuracy: 0.9707
# Epoch 145/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.0834 - accuracy: 0.9726 - val_loss: 0.1011 - val_accuracy: 0.9699
# Epoch 146/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.0757 - accuracy: 0.9735 - val_loss: 0.0981 - val_accuracy: 0.9711
# Epoch 147/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.0775 - accuracy: 0.9747 - val_loss: 0.1009 - val_accuracy: 0.9720
# Epoch 148/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.0764 - accuracy: 0.9742 - val_loss: 0.0990 - val_accuracy: 0.9707
# Epoch 149/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.0811 - accuracy: 0.9711 - val_loss: 0.0999 - val_accuracy: 0.9716
# Epoch 150/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.0757 - accuracy: 0.9751 - val_loss: 0.1007 - val_accuracy: 0.9707
# Epoch 151/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.0762 - accuracy: 0.9736 - val_loss: 0.1013 - val_accuracy: 0.9695
# Epoch 152/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.0795 - accuracy: 0.9706 - val_loss: 0.0984 - val_accuracy: 0.9711
# Epoch 153/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.0746 - accuracy: 0.9733 - val_loss: 0.1002 - val_accuracy: 0.9707
# Epoch 154/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.0773 - accuracy: 0.9742 - val_loss: 0.1008 - val_accuracy: 0.9707
# Epoch 155/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.0785 - accuracy: 0.9738 - val_loss: 0.0990 - val_accuracy: 0.9724
# Epoch 156/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.0775 - accuracy: 0.9724 - val_loss: 0.1002 - val_accuracy: 0.9716
# Epoch 157/250
# 5577/5577 [==============================] - 1s 262us/sample - loss: 0.0753 - accuracy: 0.9744 - val_loss: 0.0981 - val_accuracy: 0.9732
# Epoch 158/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.0753 - accuracy: 0.9742 - val_loss: 0.0993 - val_accuracy: 0.9720
# Epoch 159/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.0775 - accuracy: 0.9720 - val_loss: 0.0988 - val_accuracy: 0.9720
# Epoch 160/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.0744 - accuracy: 0.9745 - val_loss: 0.0985 - val_accuracy: 0.9720
# Epoch 161/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.0748 - accuracy: 0.9729 - val_loss: 0.0973 - val_accuracy: 0.9724
# Epoch 162/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.0775 - accuracy: 0.9729 - val_loss: 0.0993 - val_accuracy: 0.9707
# Epoch 163/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.0755 - accuracy: 0.9758 - val_loss: 0.0990 - val_accuracy: 0.9711
# Epoch 164/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.0742 - accuracy: 0.9754 - val_loss: 0.0971 - val_accuracy: 0.9737
# Epoch 165/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.0748 - accuracy: 0.9747 - val_loss: 0.0978 - val_accuracy: 0.9720
# Epoch 166/250
# 5577/5577 [==============================] - 1s 262us/sample - loss: 0.0729 - accuracy: 0.9745 - val_loss: 0.0972 - val_accuracy: 0.9716
# Epoch 167/250
# 5577/5577 [==============================] - 1s 265us/sample - loss: 0.0774 - accuracy: 0.9745 - val_loss: 0.0982 - val_accuracy: 0.9711
# Epoch 168/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.0745 - accuracy: 0.9740 - val_loss: 0.0971 - val_accuracy: 0.9724
# Epoch 169/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.0699 - accuracy: 0.9762 - val_loss: 0.0979 - val_accuracy: 0.9716
# Epoch 170/250
# 5577/5577 [==============================] - 1s 265us/sample - loss: 0.0731 - accuracy: 0.9754 - val_loss: 0.1003 - val_accuracy: 0.9699
# Epoch 171/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.0758 - accuracy: 0.9758 - val_loss: 0.0983 - val_accuracy: 0.9716
# Epoch 172/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.0726 - accuracy: 0.9744 - val_loss: 0.0986 - val_accuracy: 0.9699
# Epoch 173/250
# 5577/5577 [==============================] - 1s 265us/sample - loss: 0.0720 - accuracy: 0.9758 - val_loss: 0.0973 - val_accuracy: 0.9703
# Epoch 174/250
# 5577/5577 [==============================] - 1s 262us/sample - loss: 0.0696 - accuracy: 0.9754 - val_loss: 0.0968 - val_accuracy: 0.9720
# Epoch 175/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.0719 - accuracy: 0.9758 - val_loss: 0.0972 - val_accuracy: 0.9720
# Epoch 176/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.0722 - accuracy: 0.9753 - val_loss: 0.0975 - val_accuracy: 0.9724
# Epoch 177/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.0717 - accuracy: 0.9762 - val_loss: 0.0981 - val_accuracy: 0.9716
# Epoch 178/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.0692 - accuracy: 0.9762 - val_loss: 0.0990 - val_accuracy: 0.9716
# Epoch 179/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.0732 - accuracy: 0.9749 - val_loss: 0.0957 - val_accuracy: 0.9707
# Epoch 180/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.0729 - accuracy: 0.9756 - val_loss: 0.0990 - val_accuracy: 0.9699
# Epoch 181/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.0716 - accuracy: 0.9756 - val_loss: 0.0958 - val_accuracy: 0.9711
# Epoch 182/250
# 5577/5577 [==============================] - 1s 266us/sample - loss: 0.0669 - accuracy: 0.9792 - val_loss: 0.1000 - val_accuracy: 0.9699
# Epoch 183/250
# 5577/5577 [==============================] - 1s 265us/sample - loss: 0.0705 - accuracy: 0.9747 - val_loss: 0.0985 - val_accuracy: 0.9724
# Epoch 184/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.0716 - accuracy: 0.9769 - val_loss: 0.0965 - val_accuracy: 0.9703
# Epoch 185/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.0706 - accuracy: 0.9778 - val_loss: 0.0980 - val_accuracy: 0.9707
# Epoch 186/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.0706 - accuracy: 0.9760 - val_loss: 0.0964 - val_accuracy: 0.9707
# Epoch 187/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.0685 - accuracy: 0.9756 - val_loss: 0.0965 - val_accuracy: 0.9711
# Epoch 188/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.0674 - accuracy: 0.9754 - val_loss: 0.0968 - val_accuracy: 0.9711
# Epoch 189/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.0706 - accuracy: 0.9756 - val_loss: 0.0967 - val_accuracy: 0.9699
# Epoch 190/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.0700 - accuracy: 0.9779 - val_loss: 0.0969 - val_accuracy: 0.9728
# Epoch 191/250
# 5577/5577 [==============================] - 1s 265us/sample - loss: 0.0696 - accuracy: 0.9747 - val_loss: 0.0962 - val_accuracy: 0.9711
# Epoch 192/250
# 5577/5577 [==============================] - 1s 262us/sample - loss: 0.0664 - accuracy: 0.9765 - val_loss: 0.0968 - val_accuracy: 0.9716
# Epoch 193/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.0669 - accuracy: 0.9749 - val_loss: 0.0963 - val_accuracy: 0.9699
# Epoch 194/250
# 5577/5577 [==============================] - 1s 262us/sample - loss: 0.0663 - accuracy: 0.9753 - val_loss: 0.1001 - val_accuracy: 0.9699
# Epoch 195/250
# 5577/5577 [==============================] - 1s 265us/sample - loss: 0.0695 - accuracy: 0.9769 - val_loss: 0.0973 - val_accuracy: 0.9699
# Epoch 196/250
# 5577/5577 [==============================] - 1s 262us/sample - loss: 0.0681 - accuracy: 0.9769 - val_loss: 0.0942 - val_accuracy: 0.9703
# Epoch 197/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.0669 - accuracy: 0.9781 - val_loss: 0.0950 - val_accuracy: 0.9720
# Epoch 198/250
# 5577/5577 [==============================] - 1s 263us/sample - loss: 0.0652 - accuracy: 0.9788 - val_loss: 0.0959 - val_accuracy: 0.9707
# Epoch 199/250
# 5577/5577 [==============================] - 1s 264us/sample - loss: 0.0663 - accuracy: 0.9769 - val_loss: 0.0947 - val_accuracy: 0.9720
# Epoch 200/250
# 5500/5577 [============================>.] - ETA: 0s - loss: 0.0689 - accuracy: 0.9747 ETA: 0s - loss: 0.0669 -

# %% [markdown]
# **Save Model and its History**

# %%
names = ['cnn-3-ndropout', 'cnn-3-dropout','cnn-4-ndropout', 'cnn-4-dropout']
name = names[1]
# save scaler
nn.save_scaler(scaler, name=name)
# save history
nn.save_history(history, name=name)
# save model
nn.save_model(model, name=name)
# Out:
# Saving scaler .... Done.
# Saving history .... Done.
# Saving history .... Done.

# %% [markdown]
# **Plot history**

# %%
names = ['cnn-3-ndropout', 'cnn-3-dropout','cnn-4-ndropout', 'cnn-4-dropout']
name = names[1]
history = nn.load_history(name=name)
scaler = nn.load_scaler(name=name)
model = nn.load_model(name=name)
# summarize history for accuracy
nn.show_history(history, figsize=(8,6),font=font)
nn.visualization(model, figsize=(8,3), conv_layer_number=0)

# %% [markdown]
# **Visualise layers**

# %%
transforms, transforms_params = ['slice', 'scale'], [[1.5,9.5],[0,1]]
nn = NeuralNetwork(dataset_loc, database_loc, site, transforms, transforms_params)
model = nn.load_model(name=name)
history = nn.load_history(name=name)
nn.visualization(model, figsize=(8,3), conv_layer_number=0)
nn.show_history(history, figsize=(8,6),font=font)

# %%
transforms, transforms_params = ['slice', 'zscore','scale'], [[1.5,9.5],None,[0,1]]
nn = NeuralNetworkDetector(dataset_loc, database_loc, site, transforms, transforms_params)
model = nn.load_model(name=name)
history = nn.load_history(name=name)
nn.visualization(model, figsize=(8,3), conv_layer_number=0)
nn.show_history(history, figsize=(8,6),font=font)
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 2, 44, 156)        3434
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 2, 22, 78)         0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 2, 22, 78)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 22, 78)         7064
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 8, 11, 39)         0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 8, 11, 39)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 11, 39)        6288
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 16, 5, 19)         0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 16, 5, 19)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1520)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 512)               778752
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 861,460
# Trainable params: 861,460
# Non-trainable params: 0
# _________________________________________________________________

# %%
_, _, f,t = model.layers[0].input_shape
f,t
# Out:
# (44, 156)
